# %% [markdown]
# # 08_paper_figures_tables
#
# Regenerate publication figures and LaTeX-ready tables from saved result artifacts.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
