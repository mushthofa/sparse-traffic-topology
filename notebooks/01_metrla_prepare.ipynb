# %% [markdown]
# # 01_metrla_prepare
#
# Prepare METR-LA graph and dense traffic signal matrix for controlled sparse-observation experiments.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
