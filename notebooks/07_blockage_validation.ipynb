# %% [markdown]
# # 07_blockage_validation
#
# Validate road criticality against OD delay and network-efficiency loss under road removal.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
