# %% [markdown]
# # 06_topological_criticality
#
# Compute persistence-perturbation road criticality and temporal criticality profiles.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
