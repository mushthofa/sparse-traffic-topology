# %% [markdown]
# # 05_bandung_persistent_topology
#
# Compute Bandung D0/D1, Betti curves, TP0/TP1, pTHI, and 21x21 topological distances.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
