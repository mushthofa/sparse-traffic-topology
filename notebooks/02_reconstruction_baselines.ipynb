# %% [markdown]
# # 02_reconstruction_baselines
#
# Implement and compare global multiplier, road-class, nearest-neighbor, and graph baselines.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
