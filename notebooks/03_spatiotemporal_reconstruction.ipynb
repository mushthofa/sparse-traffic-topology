# %% [markdown]
# # 03_spatiotemporal_reconstruction
#
# Fit the proposed spatial-temporal graph regularized reconstruction and cross-validate hyperparameters.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
