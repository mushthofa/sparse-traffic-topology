# %% [markdown]
# # 04_topology_fidelity
#
# Measure persistence-diagram, Betti-curve, and pTHI fidelity under simulated sparse sensing.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
