# %% [markdown]
# # 00_bandung_data_audit
#
# Audit the 2,100 Google observations, route consistency, self-loops, temporal coverage, and QC decisions.
#
# **Rule:** keep reusable logic in `src/traffic_thi/`; this notebook orchestrates experiments and visualization only.
